# %%
import arcpy
import matplotlib.pyplot as plt

# %%
import numpy,os
path = os.getcwd()

# %%
dem = "../data/dem/Himalaya100.tif"

# %%
inRas = arcpy.Raster(dem)
lowerLeft = arcpy.Point(inRas.extent.XMin,inRas.extent.YMin)
cellSize = inRas.meanCellWidth

# %%
lowerLeft
# Out:
# <Point (486387.9265206632, 3089700.726101742, #, #)>

# %%
cellSize
# Out:
# 100.0

# %%
arr = arcpy.RasterToNumPyArray(inRas,nodata_to_value=0)

# %%
arr
# Out:
# array([[6163, 6201, 6197, ..., 6097, 6083, 6063],
#        [6059, 6099, 6125, ..., 6096, 6082, 6062],
#        [6042, 6074, 6104, ..., 6086, 6069, 6052],
#        ...,
#        [5169, 5172, 5166, ..., 5928, 5918, 5850],
#        [5145, 5155, 5154, ..., 5900, 5874, 5843],
#        [5170, 5151, 5154, ..., 5873, 5858, 5823]], dtype=int16)

# %%
arr.shape
# Out:
# (123, 135)

# %%
numpy.max(arr)
# Out:
# 8821

# %%
numpy.mean(arr)
# Out:
# 6384.972116832279

# %%
ax = plt.figure(figsize=(7,7))
plt.imshow(arr,cmap=plt.cm.gray)

# %%
ax = plt.figure(figsize=(7,7))
#plt.imshow(arr,cmap=plt.cm.gist_earth)
plt.imshow(arr,cmap=plt.cm.Reds)

# %%
arr2 = numpy.where(arr>6500,6500,arr)

# %%
numpy.max(arr2)
# Out:
# 6500

# %%
newRaster = arcpy.NumPyArrayToRaster(arr,lowerLeft,cellSize,
                                     value_to_nodata=0)

# %%
ax = plt.figure(figsize=(7,7))
plt.imshow(arr2,cmap=plt.cm.gist_earth)

# %%
#newRaster.save(path + "/data/dem/newDEM.tif")
