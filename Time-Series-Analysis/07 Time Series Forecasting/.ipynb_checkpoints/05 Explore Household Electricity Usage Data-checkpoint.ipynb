# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('household_power_consumption_days.csv', header=0,index_col="datetime")
#                       low_memory=False, infer_datetime_format=True, engine='c',
#                       parse_dates={'datetime':[0,1]}, , index_col="datetime"
#                       index_col="datetime"
# dataset = pd.read_csv('household_power_consumption.txt', sep=';', header=0,
#                       parse_dates={'datetime':[0,1]}, index_col=['datetime'])

# %%
dataset.shape
# Out:
# (1442, 9)

# %%
dataset.head(10)
# Out:
#             Global_active_power  Global_reactive_power    Voltage  \
# datetime
# 2006-12-16             1209.176                 34.922   93552.53
# 2006-12-17             3390.460                226.006  345725.32
# 2006-12-18             2203.826                161.792  347373.64
# 2006-12-19             1666.194                150.942  348479.01
# 2006-12-20             2225.748                160.998  348923.61
# 2006-12-21             1723.288                144.434  347096.41
# 2006-12-22             2341.338                186.906  347305.75
# 2006-12-23             4773.386                221.470  345795.95
# 2006-12-24             2550.012                149.900  348029.91
# 2006-12-25             2743.120                240.280  350495.90
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# datetime
# 2006-12-16            5180.8             0.0           546.0          4926.0
# 2006-12-17           14398.6          2033.0          4187.0         13341.0
# 2006-12-18            9247.2          1063.0          2621.0         14018.0
# 2006-12-19            7094.0           839.0          7602.0          6197.0
# 2006-12-20            9313.0             0.0          2648.0         14063.0
# 2006-12-21            7266.4          1765.0          2692.0         10456.0
# 2006-12-22            9897.0          3151.0           350.0         11131.0
# 2006-12-23           20200.4          2669.0           425.0         14726.0
# 2006-12-24           11002.2          1703.0          5082.0          6891.0
# 2006-12-25           11450.2          6620.0          1962.0          5795.0
#
#             sub_metering_4
# datetime
# 2006-12-16    14680.933319
# 2006-12-17    36946.666732
# 2006-12-18    19028.433281
# 2006-12-19    13131.900043
# 2006-12-20    20384.800011
# 2006-12-21    13808.466697
# 2006-12-22    24390.300043
# 2006-12-23    61736.433386
# 2006-12-24    28824.199967
# 2006-12-25    31341.666629

# %%
dataset.isna().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# sub_metering_4           0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# sub_metering_4           0
# dtype: int64

# %%
dataset.iloc[dataset.values == '?'].count()
# Out:
# C:\Users\xyt556\AppData\Local\Temp\179\ipykernel_78776\2368395356.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   dataset.iloc[dataset.values == '?'].count()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 dataset.iloc[dataset.values == '?'].count()
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\indexing.py:1517, in _iLocIndexer._getitem_axis(self, key, axis)
#    1515 key = item_from_zerodim(key)
#    1516 if not is_integer(key):
# -> 1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
dataset.replace('?', np.nan, inplace=True)

# %%
dataset.isna().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# sub_metering_4           0
# dtype: int64

# %%
dataset.iloc[dataset.values == '?'].count()
# Out:
# C:\Users\xyt556\AppData\Local\Temp\179\ipykernel_78776\2368395356.py:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   dataset.iloc[dataset.values == '?'].count()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 dataset.iloc[dataset.values == '?'].count()
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\indexing.py:1517, in _iLocIndexer._getitem_axis(self, key, axis)
#    1515 key = item_from_zerodim(key)
#    1516 if not is_integer(key):
# -> 1517     raise TypeError("Cannot index by location index with a non-integer key")
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
values = dataset.values.astype('float32')
dataset['sub_metering_4'] = (values[:,0] * 1000 / 60) - (values[:,4] + values[:,5] + values[:,6])

# %%
dataset.to_csv('household_power_consumption.csv')

# %%
dataset = pd.read_csv('household_power_consumption.csv', header=0, 
                   infer_datetime_format=True, engine='c',
                   parse_dates=['datetime'], index_col=['datetime'])

# %%
dataset.head(10)
# Out:
#             Global_active_power  Global_reactive_power    Voltage  \
# datetime
# 2006-12-16             1209.176                 34.922   93552.53
# 2006-12-17             3390.460                226.006  345725.32
# 2006-12-18             2203.826                161.792  347373.64
# 2006-12-19             1666.194                150.942  348479.01
# 2006-12-20             2225.748                160.998  348923.61
# 2006-12-21             1723.288                144.434  347096.41
# 2006-12-22             2341.338                186.906  347305.75
# 2006-12-23             4773.386                221.470  345795.95
# 2006-12-24             2550.012                149.900  348029.91
# 2006-12-25             2743.120                240.280  350495.90
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# datetime
# 2006-12-16            5180.8             0.0           546.0          4926.0
# 2006-12-17           14398.6          2033.0          4187.0         13341.0
# 2006-12-18            9247.2          1063.0          2621.0         14018.0
# 2006-12-19            7094.0           839.0          7602.0          6197.0
# 2006-12-20            9313.0             0.0          2648.0         14063.0
# 2006-12-21            7266.4          1765.0          2692.0         10456.0
# 2006-12-22            9897.0          3151.0           350.0         11131.0
# 2006-12-23           20200.4          2669.0           425.0         14726.0
# 2006-12-24           11002.2          1703.0          5082.0          6891.0
# 2006-12-25           11450.2          6620.0          1962.0          5795.0
#
#             sub_metering_4
# datetime
# 2006-12-16       14680.934
# 2006-12-17       36946.668
# 2006-12-18       19028.434
# 2006-12-19       13131.900
# 2006-12-20       20384.800
# 2006-12-21       13808.467
# 2006-12-22       24390.300
# 2006-12-23       61736.430
# 2006-12-24       28824.200
# 2006-12-25       31341.668

# %%
dataset.shape
# Out:
# (1442, 8)

# %%
dataset.columns
# Out:
# Index(['Global_active_power', 'Global_reactive_power', 'Voltage',
#        'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3', 'sub_metering_4'],
#       dtype='object')

# %%
def plot_features(dataset):
    plt.figure(figsize=(16,12), dpi=200)
    for i in range(len(dataset.columns)):
        plt.subplot(len(dataset.columns), 1, i+1)
        feature_name = dataset.columns[i]
        plt.plot(dataset[feature_name])
        plt.title(feature_name, y=0)
        plt.grid(linestyle='--', alpha=0.5)
        
    plt.tight_layout()
    plt.show()
plot_features(dataset)

# %%
year_2006 = dataset['2006']
# Out:
# C:\Users\xyt556\AppData\Local\Temp\179\ipykernel_78776\620309623.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   year_2006 = dataset['2006']

# %%
year_2006.head()
# Out:
#             Global_active_power  Global_reactive_power    Voltage  \
# datetime
# 2006-12-16             1209.176                 34.922   93552.53
# 2006-12-17             3390.460                226.006  345725.32
# 2006-12-18             2203.826                161.792  347373.64
# 2006-12-19             1666.194                150.942  348479.01
# 2006-12-20             2225.748                160.998  348923.61
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# datetime
# 2006-12-16            5180.8             0.0           546.0          4926.0
# 2006-12-17           14398.6          2033.0          4187.0         13341.0
# 2006-12-18            9247.2          1063.0          2621.0         14018.0
# 2006-12-19            7094.0           839.0          7602.0          6197.0
# 2006-12-20            9313.0             0.0          2648.0         14063.0
#
#             sub_metering_4
# datetime
# 2006-12-16       14680.934
# 2006-12-17       36946.668
# 2006-12-18       19028.434
# 2006-12-19       13131.900
# 2006-12-20       20384.800

# %%
year_2006.index.values
# Out:
# array(['2006-12-16T00:00:00.000000000', '2006-12-17T00:00:00.000000000',
#        '2006-12-18T00:00:00.000000000', '2006-12-19T00:00:00.000000000',
#        '2006-12-20T00:00:00.000000000', '2006-12-21T00:00:00.000000000',
#        '2006-12-22T00:00:00.000000000', '2006-12-23T00:00:00.000000000',
#        '2006-12-24T00:00:00.000000000', '2006-12-25T00:00:00.000000000',
#        '2006-12-26T00:00:00.000000000', '2006-12-27T00:00:00.000000000',
#        '2006-12-28T00:00:00.000000000', '2006-12-29T00:00:00.000000000',
#        '2006-12-30T00:00:00.000000000', '2006-12-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
def plot_year_gap(dataset, years_list):
    plt.figure(figsize=(16,12), dpi=150)
    for i in range(len(years_list)):
        ax = plt.subplot(len(years_list), 1, i+1)
        ax.set_ylabel(r'$KW$')
        
        year = years_list[i]
        year_data = dataset[str(year)]
        
        plt.plot(year_data['Global_active_power'])
        plt.title(str(year), y=0, loc='left')
        plt.grid(linestyle='--', alpha=0.5)
        plt.xticks(rotation=0)
    
    plt.tight_layout()
    plt.show()
    
years = ['2007', '2008', '2009', '2010']
plot_year_gap(dataset, years)
# Out:
# C:\Users\xyt556\AppData\Local\Temp\179\ipykernel_78776\259313179.py:8: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   year_data = dataset[str(year)]

# %%
def plot_month_gap(dataset, year, months_list):
    plt.figure(figsize=(16,12), dpi=150)
    for i in range(len(months_list)):
        ax = plt.subplot(len(months_list), 1, i+1)
        ax.set_ylabel(r'$KW$')
        
        month = str(year) + '-' + str(months_list[i])
        month_data = dataset[month]
        
        plt.plot(month_data['Global_active_power'])
        plt.title(month, y=0, loc='left')
        plt.grid(linestyle='--', alpha=0.5)
        plt.xticks(rotation=0)
    
    plt.tight_layout()
    plt.show()

year = 2008
months = [i for i in range(1, 13)]
plot_month_gap(dataset, year, months)

# %%
def plot_day_gap(dataset, year, month, days_list):
    plt.figure(figsize=(20,24), dpi=150)
    for i in range(len(days_list)):
        ax = plt.subplot(len(days_list), 1, i+1)
        ax.set_ylabel(r'$KW$',size=10)
        
        day = str(year) + '-0' + str(month) + '-' + str(days_list[i])
        day_data = dataset[day]
        
        gcp_data = day_data['Global_active_power']
        plt.plot(gcp_data)
        plt.title(day, y=0, loc='left', size=10)
        plt.grid(linestyle='--', alpha=0.5)
        plt.xticks(rotation=0)
    
    plt.show()

year = 2008
month = 8
days = [i for i in range(1, 32)]
plot_day_gap(dataset, year, month, days)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2008-08-1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 21>()
#      19 month = 8
#      20 days = [i for i in range(1, 32)]
# ---> 21 plot_day_gap(dataset, year, month, days)
#
# Input In [42], in plot_day_gap(dataset, year, month, days_list)
#       5 ax.set_ylabel(r'$KW$',size=10)
#       7 day = str(year) + '-0' + str(month) + '-' + str(days_list[i])
# ----> 8 day_data = dataset[day]
#      10 gcp_data = day_data['Global_active_power']
#      11 plt.plot(gcp_data)
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\PycharmProjects\big_data\envi\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '2008-08-1'

# %%
def dataset_distribution(dataset):
    plt.figure(figsize=(16,12), dpi=150)
    for i in range(len(dataset.columns)):
        ax = plt.subplot(len(dataset.columns), 1, i+1)
        ax.set_ylabel(r'$numbers$',size=10)
        
        feature_name = dataset.columns[i]
        
        dataset[feature_name].hist(bins=100)
        
        plt.title(feature_name, y=0, loc='right', size=20)
        plt.grid(linestyle='--', alpha=0.5)
        plt.xticks(rotation=0)
        
    plt.tight_layout()
    plt.show()

dataset_distribution(dataset)

# %%
def plot_year_dist(dataset, years_list):
    plt.figure(figsize=(16,12), dpi=150)
    for i in range(len(years_list)):
        ax = plt.subplot(len(years_list), 1, i+1)
        ax.set_ylabel(r'$numbers$', size=10)
        ax.set_xlabel(r'$KW$', size=10)
        ax.set_xlim(0, 5) # 设置x轴显示限制，保证每个子图x刻度相同

        year = years_list[i]
        year_data = dataset[str(year)]
        
        year_data['Global_active_power'].hist(bins=100, histtype='bar')
        plt.title(str(year), y=0, loc='right', size=10)
        plt.grid(linestyle='--', alpha=0.5)
        plt.xticks(rotation=0)
    
    plt.tight_layout()
    plt.show()
    
years = ['2007', '2008', '2009', '2010']
plot_year_dist(dataset, years)
# Out:
# C:\Users\xyt556\AppData\Local\Temp\179\ipykernel_78776\2798151849.py:10: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   year_data = dataset[str(year)]

# %%
def plot_month_dist(dataset, year, months_list):
    plt.figure(figsize=(16,12), dpi=150)
    for i in range(len(months_list)):
        ax = plt.subplot(len(months_list), 1, i+1)
        ax.set_ylabel(r'$numbers$', size=10)
        ax.set_xlabel(r'$KW$', size=10)
        ax.set_xlim(0, 5)
        
        month = str(year) + '-' + str(months_list[i])
        month_data = dataset[month]
        
        month_data['Global_active_power'].hist(bins=100, histtype='bar')
        plt.title(month, y=0, loc='right', size=10)
        plt.grid(linestyle='--', alpha=0.5)
        plt.xticks(rotation=0)
    
    plt.tight_layout()
    plt.show()

year = 2008
months = [i for i in range(1, 13)]
plot_month_dist(dataset, year, months)
