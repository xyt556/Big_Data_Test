# %%
import numpy as np
import pandas as pd
import math


data = np.random.randint(1,365,size=290)
data
# Out:
# array([277, 204, 117,  44, 251, 273, 252, 150,  69, 296,   3, 224, 124,
#        319,  53,  20, 329,  93,  11,  12,  40, 301, 345,  37, 329, 175,
#         80,  70, 311, 348, 285, 217,  41,  14, 254, 343, 218,  44,  28,
#        267,  26, 205, 119, 225, 245, 193, 230, 260, 200, 261,  89, 103,
#        357, 122, 270, 126, 245,  54, 186, 222, 110,  36, 343, 262, 218,
#        334, 313, 313, 277, 224, 294, 163, 265, 299, 315,   7, 285,  67,
#        182, 138, 106,   8,  87, 274, 144, 337, 102, 258, 282,  84, 349,
#        199,  43, 333, 232, 196, 329, 178, 184, 318, 333,  17,  96,  45,
#         23, 258, 238, 107, 140, 264, 200, 176, 211, 262, 234,  86, 163,
#        332,  66, 245, 254, 251,  79, 356,  37,  55, 262, 213, 344, 192,
#         51,  26,  50, 144,  48, 232, 310,  13, 253,  61,  22, 115, 214,
#        188, 312, 315, 282,  31, 115, 192, 106, 279, 173, 220, 338, 320,
#         83,   1, 160, 121,  52,   9,  20,  76, 102, 111, 312, 317, 204,
# ...
