# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as pml
import seaborn as sns
# %matplotlib inline

from scipy import stats,integrate

# %%
# tips = sns.load_dataset("tips")
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 函数FacetGrid() 函数： 可以展示数据中的很多子集
# 展示画图区域
g = sns.FacetGrid(tips,col = "time")
# 通过map()s 函数，实际的画图形,拿着画板变量g ,去画图
g.map(plt.hist,"tip")                 # 传进来的是plt.hist,画出条形图，
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %% [markdown]
# 笔记：
# - 第一点：map() 函数：
#   第一个参数：要画成的图形类型；x,y 轴的坐标轴，透明度

# %%
g = sns.FacetGrid(tips,col = "sex",hue = "smoker")

# plt.scatter: 画出散点图
g.map(plt.scatter,"total_bill","tip",alpha = 0.5)
g.add_legend()
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
g = sns.FacetGrid(tips,row = "smoker",col = 'time',margin_titles = True)

# fit_reg = True, 画出回归的线    x_jitter： 指定一定的偏离程度
g.map(sns.regplot,"size","total_bill",color = "g",fit_reg = True,x_jitter = .1)
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
# 设定一定的布局项， size 每个面的高度; aspect 纵横比；
g = sns.FacetGrid(tips,col = "day",height = 4,aspect = 0.5)
g.map(sns.barplot,"sex","total_bill")
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# ...

# %%
from pandas import Categorical
order_days = tips.day.value_counts().index
print(order_days)

# 自己指定画图的顺序
ordered_days = Categorical(['Thur', 'Fri', 'Sat', 'Sun'])

# FacetGrid：指定用pandas 格式：DataFrame 格式
g = sns.FacetGrid(tips,row= "day",row_order = ordered_days,height = 1.7,aspect = 2)
g.map(sns.boxplot,"total_bill",order =False)
# Out:
# CategoricalIndex(['Sat', 'Sun', 'Thur', 'Fri'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category')

# %% [markdown]
# # FacetGrid() 函数绘制多变量

# %%
pal = dict(Lunch = 'green',Dinner = "red")
g = sns.FacetGrid(tips,hue = "time",palette = pal,height = 4)

# s = 50： 圆圈的大小
g.map(plt.scatter,"total_bill","tip",s = 50,alpha = 0.4,linewidth = 0.5,
      edgecolor = "white")
g.add_legend()
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
g = sns.FacetGrid(tips,hue = "sex",palette = "Set1",height = 4,
                  hue_kws = {"marker":["^","o"]})

# s = 50： 圆圈的大小
g.map(plt.scatter,"total_bill","tip",s = 50,alpha = 0.4,linewidth = 0.5,
      edgecolor = "white")
g.add_legend()
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
with sns.axes_style("white"):
    g = sns.FacetGrid(tips,row = "sex",col = "smoker",margin_titles = True,height = 4)
g.map(plt.scatter,"total_bill","tip",color= "g",edgecolor = 'white',lw = 0.5)
g.set_axis_labels("Total_bill","tips")
g.set(xticks = [10,30,50],yticks = [2,6,10])
g.fig.subplots_adjust(wspace = 0.62,hspace = 0.32)
# Out:
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# F:\Big_Data_Test\venv\lib\site-packages\seaborn\axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
# iris = sns.load_dataset("iris")
iris = pd.read_csv('iris.csv')
# 指定所要画的图的风格PairGrid
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
# 指定对角线上画什么图非对角线上画什么图
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
# 指定对角线上画什么图非对角线上画什么图
# hue = 'species': 添加类别
g = sns.PairGrid(iris,hue = 'species')
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
#画出特定特征的图：vars 指定
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris,vars = ["sepal_length","sepal_width"],hue = "species")
g.map(plt.scatter)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File D:\Python310\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File D:\Python310\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Python310\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# 可以指定调色板的颜色
g = sns.PairGrid(tips,hue = "size",palette = "GnBu_d")
g.map(plt.scatter,s = 50,edgecolor = "white")
g.add_legend()

# %% [markdown]
# # 热度图绘制

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

np.random.seed(0)
sns.set()

uniform_data = np.random.rand(3,3)
print(uniform_data)
heatmap = sns.heatmap(uniform_data)
# Out:
# [[0.5488135  0.71518937 0.60276338]
#  [0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276]]

# %%
# 对右边的小的调色板进行一个小的设置
ax = sns.heatmap(uniform_data,vmin = 0.6,vmax = 0.9)

# %%
np.random.seed(0)
normal_data = np.random.rand(3,3)
print(normal_data)

# center = 0: 以0 为中心画数据
ax = sns.heatmap(normal_data,center = 0)
# Out:
# [[0.5488135  0.71518937 0.60276338]
#  [0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276]]

# %%
# 读取数据
iris= sns.load_dataset("iris")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File D:\Python310\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File D:\Python310\lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Python310\lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327     body = _encode(body, 'body')
# -> 1328 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
# iris = iris.pivot("species","sepal_width")
# print(iris)
# ax = sns.heatlplot(iris)
