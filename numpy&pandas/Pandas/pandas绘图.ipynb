# %% [markdown]
# Pandas 在数据分析、数据可视化方面有着较为广泛的应用，Pandas 对 Matplotlib 绘图软件包的基础上单独封装了一个plot()接口，通过调用该接口可以实现常用的绘图操作。本节我们深入讲解一下 Pandas 的绘图操作。
#
# Pandas 之所以能够实现了数据可视化，主要利用了 Matplotlib 库的 plot() 方法，它对 plot() 方法做了简单的封装，因此您可以直接调用该接口。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']     # 用来显示中文标签
plt.rcParams['axes.unicode_minus'] = False       # 用来正常显示负号
#创建包含时间序列的数据
df = pd.DataFrame(np.random.randn(8,4),index=pd.date_range('2/1/2020',periods=8), columns=list('ABCD'))
df.plot()
plt.plot()
# Out:
# []

# %% [markdown]
# 如上图所示，如果行索引中包含日期，Pandas 会自动调用 gct().autofmt_xdate() 来格式化 x 轴。
#
# 除了使用默认的线条绘图外，您还可以使用其他绘图方式，如下所示：
#
#     柱状图：bar() 或 barh()
#     直方图：hist()
#     箱状箱：box()
#     区域图：area()
#     散点图：scatter()
#
#
# 通过关键字参数kind可以把上述方法传递给 plot()。

# %%
df = pd.DataFrame(np.random.rand(10,5),columns=['a','b','c','d','e'])
#或使用df.plot(kind="bar")
df.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# 通过设置参数stacked=True可以生成柱状堆叠图，示例如下：

# %%
df.plot(kind="bar",stacked=True)
#或者使用df.plot.bar(stacked="True")
# Out:
# <AxesSubplot: >

# %%
# df.plot.barh(stacked=True)
df.plot(kind='barh',stacked=True)
# Out:
# <AxesSubplot: >

# %%
df.plot.box()
# Out:
# <AxesSubplot: >

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 df.plot.area()
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_core.py:1558, in PlotAccessor.area(self, x, y, **kwargs)
#    1487 def area(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1488     """
#    1489     Draw a stacked area plot.
#    1490
#    (...)
#    1556         >>> ax = df.plot.area(x='day')
#    1557     """
# -> 1558     return self(kind="area", x=x, y=y, **kwargs)
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_core.py:1001, in PlotAccessor.__call__(self, *args, **kwargs)
#     998             label_name = label_kw or data.columns
#     999             data.columns = label_name
# -> 1001 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:1377, in LinePlot._make_plot(self)
#    1374 label = self._mark_right_label(label, index=i)
#    1375 kwds["label"] = label
# -> 1377 newlines = plotf(
#    1378     ax,
#    1379     x,
#    1380     y,
#    1381     style=style,
#    1382     column_num=i,
#    1383     stacking_id=stacking_id,
#    1384     is_errorbar=is_errorbar,
#    1385     **kwds,
#    1386 )
#    1387 self._append_legend_handles_labels(newlines[0], label)
#    1389 if self._is_ts_plot():
#    1390
#    1391     # reset of xlim should be used for ts data
#    1392     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:1550, in AreaPlot._plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1548 if column_num == 0:
#    1549     cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1550 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
#    1552 # need to remove label, because subplots uses mpl legend as it is
#    1553 line_kwds = kwds.copy()
#
# File F:\Big_Data_Test\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:1461, in LinePlot._get_stacked_values(cls, ax, stacking_id, values, label)
#    1458 elif (values <= 0).all():
#    1459     return ax._stacker_neg_prior[stacking_id] + values
# -> 1461 raise ValueError(
#    1462     "When stacked is True, each column must be either "
#    1463     "all positive or all negative. "
#    1464     f"Column '{label}' contains both positive and negative values"
#    1465 )
#
# ValueError: When stacked is True, each column must be either all positive or all negative. Column 'A' contains both positive and negative values

# %%
df = pd.DataFrame({'A':np.random.randn(100)+2,'B':np.random.randn(100),'C':
np.random.randn(100)-2}, columns=['A', 'B', 'C'])
print(df)
#指定箱数为15
df.plot.hist(bins=15)
# Out:
#            A         B         C
# 0   2.141007 -1.262358  0.054058
# 1   2.543525 -0.810090 -1.522773
# 2   3.019953  0.343276 -2.075914
# 3   1.061664 -1.642290 -1.203612
# 4   3.272382  2.721185 -0.661587
# ..       ...       ...       ...
# 95  2.133439 -0.440069 -2.427791
# 96  1.557422 -0.207040 -1.204745
# 97  2.076823 -0.545373 -0.578955
# 98  2.523852 -1.765525 -3.784187
# 99  3.259487 -0.971372 -2.273283
#
# [100 rows x 3 columns]
# <AxesSubplot: ylabel='Frequency'>

# %%
df.diff().hist(color="r",alpha=0.5,bins=15)
# Out:
# array([[<AxesSubplot: title={'center': 'A'}>,
#         <AxesSubplot: title={'center': 'B'}>],
#        [<AxesSubplot: title={'center': 'C'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
df.plot.box()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame(np.random.rand(5, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
# Out:
# <AxesSubplot: >

# %%
df = pd.DataFrame(np.random.rand(30, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot: xlabel='a', ylabel='b'>

# %%
df = pd.DataFrame(3 * np.random.rand(4), index=['go', 'java', 'c++', 'c'], columns=['L'])
df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot: ylabel='L'>], dtype=object)
